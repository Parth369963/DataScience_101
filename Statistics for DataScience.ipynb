# %% [markdown]
# # Introduction to Statistics
#
# ### 1. Types of Statistics
#
# - Descriptive
# - Inferential
#
# ### 2. Analytics Methodology and how industry use statistics
#
# - Weather forecasting
# - Giving Insurance
# - Stock market
# - Drug effectiveness before releasing to the public
# - Diseased survival probability
# - Election winning and Exit poll prediction
# - Loan approval and fraud detection
# - Netflix/Amazon recommendation.
# - New Campaign effectiveness.
#
# ### 3. Population and Sample
#
# ### 4. Parameter and Statistics (Mean, Median and Mode)

# %% [markdown]
# ## Mean
#
# In statistics, the mean is one of the measures of central tendency, apart from the mode and median. Mean is nothing but the average of the given set of values. It denotes the equal distribution of values for a given data set. The mean, median and mode are the three commonly used measures of central tendency. To calculate the mean, we need to add the total values given in a datasheet and divide the sum by the total number of values. The Median is the middle value of a given data when all the values are arranged in ascending order. Whereas mode is the number in the list, which is repeated a maximum number of times.

# %%
import statistics as st

x = [10,20,30,40,35,40,40,50,50,50,50,45,50,60,70,80]

print (st.mean(x))

# using pandas
# import pandas as pd
# x_ = pd.DataFrame(x)
# print (x_.mean())
# Out:
# 45

# %% [markdown]
# ## Median
#
# Median, in statistics, is the middle value of the given list of data when arranged in an order. The arrangement of data or observations can be made either in ascending order or descending order.
#
# Example: The median of 2,3,4 is 3.
#
# In Maths, the median is also a type of average, which is used to find the centre value. Therefore, it is also called measure of central tendency.

# %%
print (st.median(x))
# Out:
# 47.5

# %% [markdown]
# ## Mode
#
# The mode is the value that is repeatedly occurring in a given set. We can also say that the value or number in a data set, which has a high frequency or appears more frequently, is called mode or modal value. It is one of the three measures of central tendency, apart from mean and median. For example, the mode of the set {3, 7, 8, 8, 9}, is 8. Therefore, for a finite number of observations, we can easily find the mode. A set of values may have one mode or more than one mode or no mode at all.

# %%
st.mode(x)
# Out:
# 50

# %% [markdown]
# # Uses of variable: Dependent and Independent variable.
#
# # Types of Variable: Continuous and Categorical variable.
#
# ![Screenshot%202022-10-13%20075407.png](attachment:Screenshot%202022-10-13%20075407.png)

# %% [markdown]
# # Descriptive Statistics
#
# - Measure of central tendacy (Mean, Median, Mode)
# - Measure of dispersion(spread) (variance and standard deviation)
#
#
# ##### Measure of Dispersion
#
# ![image.png](attachment:image.png)

# %%
# x1 = data, Mu = mean, N=occurances

import numpy as np
x1 = [21,33,63]

avg = np.mean(x1)
print (avg)
# Out:
# 39.0

# %%
np.sum((np.square(20 - avg) + np.square(34 - avg) + np.square(56 - avg))/3)
# Out:
# 225.0

# %%
import numpy as np
# Variance = Means of squared deviation (below)
print ('variance -', np.var(x1))

# std = sqrt of variance
print ('std. Dv -', np.std(x1))
# Out:
# variance - 312.0
# std. Dv - 17.663521732655695

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Qauntiles

# %%
import statistics as st
import pandas as pd


y = [10,20,30,40,50,60,70,80]

y_ = pd.DataFrame(y)

y_.describe()
# Out:
#                0
# count   8.000000
# mean   45.000000
# std    24.494897
# min    10.000000
# 25%    27.500000
# 50%    45.000000
# 75%    62.500000
# max    80.000000

# %% [raw]
# - Inter Quantiles => Q3-Q1
# - Quantile Range => Max - Min
# - IQRange

# %% [markdown]
# # Inferential Statistics.
#
# - Sampling data and infer the result to describe entire population.
#
# # Central Limit theorom
#
# ##### Normal Distribution - Distribution is always normal irrespective of sample size.
#
# ##### Non-Normal distribution - If sample size is adequate (appr > 30 sample), distribution starts looking normal.
#
# ![Screenshot%202022-10-15%20055716.png](attachment:Screenshot%202022-10-15%20055716.png)

# %% [markdown]
# # Types of Distribution
#
# - There are various types of distribution in statistics, But most commanly used distribution is normal distribution and Z distribution in our course
#
# ### Normal Distribution
#
# - A normal distribution is the proper term for a probability bell curve. In a normal distribution the mean is Zero and the standard deviation is
#
# ![Screenshot%202022-10-15%20060029.png](attachment:Screenshot%202022-10-15%20060029.png)

# %% [markdown]
# ### Bernoulli Distribution
#
# - It is a type of Discrete Probability distribution. The Bernoulli distribution essentially models a single trial of flipping a weighted coin. It is the probability distribution of a random variable taking on only two values, 1 ("success") and O ("failure") with complementary probabilities p and 1-p respectively. The Bernoulli distribution therefore describes events having exactly two outcomes, which are present in real life.
#
# Suppose We have a single trial of with only two possible outcomes success or failure:
#
# *Interpretation Example*
#
# - Student------- Result
# - X1------- Pass
# - X2------- Fail
# - X3------- Pass
# - X4------- Pass
# - X5------- Fail
# - X6------- Pass
# - X7-...... ????? (probability of student will fail)
#
# P(Success) = p P(Failure)= 1-p
#
# Let, X=1 when Success and X=0 when failure,
#
# Then the probability distribution function is given as: for x= (0,1)
#
# **p(x) = p^x * (1-p)^1-x = p**
#
# So, P(1) - p^1 (1-P)^0 =p
# P(O) = p^O*(1-0) 11 = 1-2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Binomial Distribution
#
# - The binomial distribution is a probability distribution that summarizes the likelihood that a value will take one of two independent values under a given set of parameters or assumptions.
#
# - The binomial distribution only counts two states, typically represented as 1 (for a success) or 0 (for a failure) given a number of trials in the data.
#
# ### Uniform Distribution
#
# - Uniform distribution refers to a type of probability distribution in which all outcomes are equally likely
#
# Example
#
# - Deck of cards - Probability of getting any perticular shape and number (1/52)
#
# **PDF, CDF**
#
# - pdf = Probability Density Function
# - cdf = Cumulative density function
#
# Probability looks at probability at one point.
#
# Cumulative is the total probability of anything below it.
#
# As you can see in the diagram below, the cumulative is much greater than the just probability because it is the sum of many, and not just of one probabilities.
#
# ![main-qimg-e50787cd6024e1945ef5632192b70a69%20%281%29.webp](attachment:main-qimg-e50787cd6024e1945ef5632192b70a69%20%281%29.webp)
